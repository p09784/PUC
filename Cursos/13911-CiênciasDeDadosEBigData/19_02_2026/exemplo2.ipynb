# %%
# !pip install pandas
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\guale\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\guale\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas

# %%
series = pandas.Series(['hoje', 'é', 'quinta-feira', '!'])

# %%
series
# Out:
# 0            hoje
# 1               é
# 2    quinta-feira
# 3               !
# dtype: str

# %%
series [0]
# Out:
# 'hoje'

# %%
series.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
series = pandas.Series([-1, 10, 2], index = ['abacaxi', 'banana', 'cenoura'])

series.index = ['a', 'b', 'c']

series[['a', 'c']]

series > 0

series[series > 0]
# Out:
# b    10
# c     2
# dtype: int64

# %%
fruits = pandas.DataFrame(
    [
        ['kiwi', 5.69],
        ['laranja', 3.99]
    ],
    columns = ['fruta', 'preço']
)

fruits[fruits['preço'] > 4]
# Out:
#   fruta  preço
# 0  kiwi   5.69

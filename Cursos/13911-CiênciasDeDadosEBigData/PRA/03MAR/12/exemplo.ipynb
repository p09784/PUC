# %%
import pandas
import numpy

# %%
elections = pandas.read_csv('elections.csv')

# %%
print(elections.columns)
# Out:
# Index(['Year', 'Candidate', 'Party', 'Popular vote', 'Result', '%'], dtype='str')

# %%
elections.iloc[0, 1]
# Out:
# 'Andrew Jackson'

# %%
elections[((elections['Year'] == 2024) | (elections['Year'] == 2020))]
# Out:
#      Year       Candidate              Party  Popular vote Result          %
# 178  2020    Joseph Biden         Democratic      81268924    win  51.311515
# 179  2020    Donald Trump         Republican      74216154   loss  46.858542
# 180  2020    Jo Jorgensen        Libertarian       1865724   loss   1.177979
# 181  2020  Howard Hawkins              Green        405035   loss   0.255731
# 182  2024    Donald Trump         Republican      77303568    win  49.808629
# 183  2024   Kamala Harris         Democratic      75019230   loss  48.336772
# 184  2024      Jill Stein              Green        861155   loss   0.554864
# 185  2024  Robert Kennedy        Independent        756383   loss   0.487357
# 186  2024    Chase Oliver  Libertarian Party        650130   loss   0.418895

# %%
elections.groupby('candidate').agg('max')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 elections.groupby('candidate').agg('max')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'candidate'

# %%
elections[['candidate', 'year', 'party']].groupby('candidate').agg('max')

# %%
elections.groupby('candidate').count()
# Quantidade de vezez que cada candidato apareceu

# %%
elections.groupby('candidate').value_counts()
# Mostra os dados agruoados por candidato e por ano, partido, etc

# %%
elections.groupby('Year').filter(lambda x: x['%'].max() > 45)
# Filtra os anos em que algum candidato teve mais de 45% dos votos

# %%
elections.lambda x: x['%'].sum > 45
